# %% [markdown]
# # LAB 1 (IN-LAB)

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
ps = PorterStemmer()
sentence = "running is a art. killing is sport"
words = word_tokenize(sentence)
print(words)

for w in words:
    print(w, " : ", ps.stem(w))
# Out:
# ['running', 'is', 'a', 'art', '.', 'killing', 'is', 'sport']
# running  :  run
# is  :  is
# a  :  a
# art  :  art
# .  :  .
# killing  :  kill
# is  :  is
# sport  :  sport

# %% [markdown]
# # INLAB -2

# %%
from nltk.tokenize import word_tokenize 
sentence = "Cheap ass shit man, my grandmother can do this shit. Chinnu is a lazy bitch by the way."
words = word_tokenize(sentence) 
print(words)
res = len(sentence.split()) 
print ("The number of words in string are : " +  str(res))
# Out:
# ['Cheap', 'ass', 'shit', 'man', ',', 'my', 'grandmother', 'can', 'do', 'this', 'shit', '.', 'Chinnu', 'is', 'a', 'lazy', 'bitch', 'by', 'the', 'way', '.']
# The number of words in string are : 18

# %% [markdown]
# POST LAB

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from pprint import pprint

example = "Example sentence, this is an example"
stop_words = set(stopwords.words('english'))
print(stop_words)
word = word_tokenize(example)

filtered = [w for w in word if not w in stop_words]
filtered = []

for w in word:
    if w not in stop_words:
        filtered.append(w)
print(filtered)
# Out:
# {'only', 'of', 'very', 'can', 'by', 'does', 'she', "it's", 'where', 'over', "doesn't", 'down', 'until', 'mustn', 'same', 'those', 'any', 'm', 'such', "mightn't", "wasn't", 'him', 'during', 'himself', 'them', 'yourself', 'how', 'are', 'don', 'isn', 'at', 'other', 'd', 'wouldn', 've', 'myself', 'an', 'been', 'doesn', 'having', 'mightn', 'not', 'between', 'is', 'up', 'a', 'hasn', 'more', 'below', 'll', 'too', 'as', 'against', 'so', "haven't", 'nor', 's', 'some', 'now', 'did', "weren't", 'am', 'further', 'won', 'you', 'again', "hadn't", "shouldn't", 'we', 'to', 'haven', 'own', 'why', 'it', 'o', 'above', "don't", 'will', "couldn't", 'didn', 'weren', 'into', 'on', 'all', 'just', 'when', "you're", 'if', 'with', 'ours', 'these', 'they', 'most', 'that', 're', 'ourselves', 'no', "mustn't", 'doing', 'here', "won't", 'which', 'were', 'than', 'the', 'has', 'few', 'in', 'under', 'its', 'have', 'our', 'hadn', 'before', 'out', 'theirs', 'each', 'themselves', 'or', 'both', 'whom', 'shan', 'while', "hasn't", 'because', 'had', "you'd", 'y', 'wasn', 'hers', "should've", 'from', 'about', 'off', 'ain', "aren't", 'once', 'his', 'i', 'what', 'be', 'but', 'yourselves', 'couldn', 'and', "isn't", 'he', 'was', 'for', "that'll", 'my', 'needn', "needn't", 'who', 'should', "you'll", 'her', 'herself', 'shouldn', 'their', 'me', 'aren', 'being', 'there', 'ma', "you've", 'your', "shan't", "didn't", "she's", 'this', 'then', "wouldn't", 't', 'itself', 'do', 'yours', 'through', 'after'}
# ['Example', 'sentence', ',', 'example']

# %% [markdown]
# # LAB 3

# %%
import nltk 
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
txt="the hyderabad"
print(txt)
print()
from nltk.tokenize import word_tokenize, sent_tokenize 
tokenized = sent_tokenize(txt) 
print(tokenized)
print()
for i in tokenized: 
    wordsList = nltk.word_tokenize(i) 
    tagged = nltk.pos_tag(wordsList)
    print(tagged)
# Out:
# the hyderabad
#
# ['the hyderabad']
#
# [('the', 'DT'), ('hyderabad', 'NN')]
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KIRAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\KIRAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import nltk
# Download if punkt error
# nltk.download('punkt')
from nltk import word_tokenize, RegexpTokenizer

sentence='The little mouse ate the fresh cheeze'
sentence=nltk.pos_tag(word_tokenize(sentence))

chunk_rule=r"NP:{<DT>?<JJ>*<NN>}"
chunk_parser=nltk.RegexpParser(chunk_rule)

res=chunk_parser.parse(sentence)
print(res)
# Out:
# (S
#   (NP The/DT little/JJ mouse/NN)
#   ate/VB
#   (NP the/DT fresh/JJ cheeze/NN))

# %%
text = '''Keeletehnoloogia on arvutilingvistika praktiline pool. 
Keeletehnoloogid kasutavad arvutilingvistikas välja töötatud 
teooriaid, et luua rakendusi (nt arvutiprogramme),mis võimaldavad inimkeelt arvuti abil töödelda ja mõista.Tänapäeval on keeletehnoloogia tuntumateks valdkondadeks masintõlge, arvutileksikoloogia, dialoogisüsteemid,kõneanalüüs ja kõnesüntees.''' 
#tokenize it using default tokenizer 
from nltk import Tokenizer 
tokenizer = Tokenizer() 
document = tokenizer.tokenize(text) 
#tokenized results 
print (document.word_texts) 
print (document.sentence_texts) 
print (document.paragraph_texts) 
print (document.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-a728d70e3c6e> in <module>
#       7 document = tokenizer.tokenize(text)
#       8 #tokenized results
# ----> 9 print (document.word_texts)
#      10 print (document.sentence_texts)
#      11 print (document.paragraph_texts)
#
# AttributeError: 'list' object has no attribute 'word_texts'

# %%
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
from nltk.stem.porter import PorterStemmer 
from gensim import corpora, models 
import gensim 

tokenizer = RegexpTokenizer(r'\w+') 
en_stop = get_stop_words('en') 
p_stemmer = PorterStemmer() 
   
doc_a = "Sugar is bad to consume. My sister likes to have sugar, but not my father."
doc_b = "My father spends a lot of time driving my sister around to dance practice."
doc_c = "Doctors suggest that driving may cause increased stress and blood pressure."
doc_d = "Sometimes I feel pressure to perform well at school, but my father never seems to drive my sister to do better."
doc_e = "Health experts say that Sugar is not good for your lifestyle." 
doc_set = [doc_a, doc_b, doc_c, doc_d, doc_e] 
texts = []

for i in doc_set:
    raw = i.lower() 
    tokens = tokenizer.tokenize(raw)     
    stopped_tokens = [i for i in tokens if not i in en_stop]         
    stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]         
    texts.append(stemmed_tokens)
    dictionary = corpora.Dictionary(texts)     
    corpus = [dictionary.doc2bow(text) for text in texts] 
    ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=2, id2word=dictionary, passes=20) 
print(ldamodel.print_topics(num_topics=3, num_words=3))
# Out:
# [(0, '0.047*"pressur" + 0.047*"blood" + 0.047*"caus"'), (1, '0.078*"sister" + 0.078*"father" + 0.056*"sugar"')]

# %%
pip install gensim
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/0b/66/04faeedb98bfa5f241d0399d0102456886179cabac0355475f23a2978847/gensim-3.8.3-cp37-cp37m-win_amd64.whl (24.2MB)
# Collecting Cython==0.29.14 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/1f/be/b14be5c3ad1ff73096b518be1538282f053ec34faaca60a8753d975d7e93/Cython-0.29.14-cp37-cp37m-win_amd64.whl (1.7MB)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\kiran\anaconda3\lib\site-packages (from gensim) (1.16.5)
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/74/77/744c79da6e66691e3500b6dffff29bdd787015eae817d594791edc7b719b/smart_open-2.0.0.tar.gz (103kB)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\kiran\anaconda3\lib\site-packages (from gensim) (1.3.1)
# Requirement already satisfied: six>=1.5.0 in c:\users\kiran\anaconda3\lib\site-packages (from gensim) (1.12.0)
# Requirement already satisfied: requests in c:\users\kiran\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.22.0)
# Requirement already satisfied: boto in c:\users\kiran\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Collecting boto3 (from smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/54/a4/dd860ff2dc19c63b9aeec2fa8a7a8c77e6c3275709b5962c3982f0c8e4f5/boto3-1.13.3-py2.py3-none-any.whl (128kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\kiran\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kiran\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\kiran\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kiran\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.24.2)
# Collecting s3transfer<0.4.0,>=0.3.0 (from boto3->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/69/79/e6afb3d8b0b4e96cefbdc690f741d7dd24547ff1f94240c997a26fa908d3/s3transfer-0.3.3-py2.py3-none-any.whl (69kB)
# Collecting botocore<1.17.0,>=1.16.3 (from boto3->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/25/32/513589cba34b5413965f7486d2f72a4649df1430e73f02b4067011ddedc7/botocore-1.16.3-py2.py3-none-any.whl (6.2MB)
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/a3/43/1e939e1fcd87b827fe192d0c9fc25b48c5b3368902bfb913de7754b0dc03/jmespath-0.9.5-py2.py3-none-any.whl
# Requirement already satisfied: docutils<0.16,>=0.10 in c:\users\kiran\anaconda3\lib\site-packages (from botocore<1.17.0,>=1.16.3->boto3->smart-open>=1.8.1->gensim) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\kiran\anaconda3\lib\site-packages (from botocore<1.17.0,>=1.16.3->boto3->smart-open>=1.8.1->gensim) (2.8.0)
# Building wheels for collected packages: smart-open
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Created wheel for smart-open: filename=smart_open-2.0.0-cp37-none-any.whl size=101347 sha256=e997aab2f7115fa88793e279cdbce44df0e034f23cff8386f136ea50ce785310
#   Stored in directory: C:\Users\KIRAN\AppData\Local\pip\Cache\wheels\27\65\38\8d7f5fe8d7afb4e4566587b2d1933cec185fba19257836c943
# Successfully built smart-open
# Installing collected packages: Cython, jmespath, botocore, s3transfer, boto3, smart-open, gensim
#   Found existing installation: Cython 0.29.13
#     Uninstalling Cython-0.29.13:
#       Successfully uninstalled Cython-0.29.13
# Successfully installed Cython-0.29.14 boto3-1.13.3 botocore-1.16.3 gensim-3.8.3 jmespath-0.9.5 s3transfer-0.3.3 smart-open-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
nltk.download('brown')
from nltk.corpus import brown as b
print(b.categories())

editorial=set(b.words(categories="editorial"))
editorial=sorted(editorial)
print(editorial)
x=editorial[3493:3499]
genres=['fiction','lore','belles_lettres','government','learned']
cfd=nltk.ConditionalFreqDist((genre,word) for genre in b.categories() for word in b.words(categories=genre))
cfd.tabulate(conditions=genres,samples=x)
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\KIRAN\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# ['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies', 'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance', 'science_fiction']
# ['!', '$1', '$1,000', '$1,000,000', '$1,250,000', '$1,450,000,000', '$1,750,000', '$1.1', '$133', '$15.5', '$150', '$2,000,000', '$2,300,000', '$200', '$3', '$3,000', '$3.15', '$3.22', '$30,000', '$4', '$50,400,000', '$500,000', '$550', '$580', '$590,000', '$750,000', '$8.5', '$83,750', '$84,000,000', '$9', '&', "'", "''", "'50's", "'60", "'em", '(', ')', ',', '--', '.', '1', '1,700', '1,900', '1.1', '1.5', '10', '10-year', '10-year-old', '100', '100-megaton', '100-ton', '103', '10:30', '11', '110', '12', '12-passenger', '12.8', '13', '13-16', '14', '14-15', '15', '15th', '16', '16-hour', '16-page', '160,000', '1611', '17', "1770's", '17th', '18', '180', '1821', '1881-85', '1883', '1884', '1897', '1899', '19', '1901', '1917', '192', '1920', '1930s', '1935', '1936', '1937', '1940', '1941', '1944', '1945', '1946', '1946-52', '1948', '1949', '1950', '1952', '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1961', '1962', '1963', '1980', '2', "2's", '2,000', '2,200,000', '2-year-old', '2/4', '20', '20-megaton', '200', '200,000', '200-megaton', '200-odd', '20th', '21', '21-22', '22', '22,000', '23', '23:34', '24', '25', '25,000', '25th', '26', '26-28', '27', '28', '285', '29', '29th', '3', "3's", '30', '30,000', '30-', '300,000', '31', '312', '32', '34', '34-hour', '35', '350th', '36', '367', '372', '38', '39-year-old', '4', '4-', '4/4', '40', '40,000', '400', '42', '45', '45-passenger', '450,000', '46', '5', '5-to-1', '50', '50-megaton', '500', '51', '52nd', '54th', '55,000', '57', '6', '6-1', '6.9', '60', '60,000', '60-1', '61', '64-13', '65', '689-page', '6:30', '7', '70', '700', '72', '75,000', '75,000-ton', '76', '8', '8,100', '80', '80th', '9', '9-1/2', '90', '90,000', '900', '92', '920', '96', '98', ':', ';', '?', 'A', 'A-bombs', 'A.', 'A.M.', 'A.M.A.', 'ABC', 'AEC', "AEC's", 'AFL-CIO', 'Abide', 'Academy', 'According', 'Act', 'Acting', 'Actions', 'Active', 'Actually', 'Adamo', 'Adams', 'Adaptations', 'Additional', 'Adenauer', "Adenauer's", 'Adherence', 'Adjustment', 'Adlai', 'Administration', 'Adventures', 'Advise', 'Affairs', 'Africa', 'African', 'Africans', 'After', 'Against', 'Agee', 'Agency', 'Ahmad', "Ahmad's", 'Air', 'Aircraft', "Aircraft's", 'Airways', 'Aj', 'Alabama', 'Alacrity', 'Alan', 'Alas', 'Albania', 'Albanian', 'Albanians', 'Albany', 'Alexander', 'Algeria', 'Algerian', 'All', 'Alliance', 'Already', 'Also', 'Although', 'Alva', 'Ambassador', 'Amendments', 'America', "America's", 'American', 'Americans', 'Among', 'Amory', 'Amsterdam', 'An', 'And', 'Angeles', 'Angola', 'Anne', 'Another', 'Anouilh', 'Answer', 'Anti-recession', 'Antoine', 'Antoinette', 'Any', 'Anybody', 'Anyone', 'Apocrypha', 'Apologies', 'April', 'Arab', 'Arabian', 'Arabic', 'Archbishop', 'Are', 'Area', "Aren't", 'Aristotelean-Thomistic', 'Aristotle', 'Arizona', 'Armageddon', 'Army', 'Arnold-Foster', 'Arrangements', 'Arthur', 'Article', 'Arts', 'As', 'Ashamed', 'Asia', 'Asian', 'Assassination', 'Assembly', 'Assistant', 'Association', 'Assuming', 'At', 'Atkinson', 'Atlanta', 'Atlantic', 'Atomic', 'Attlee', 'Attorney', 'Atty.', 'Audubon', 'Aug.', 'August', 'Augustin', 'Australian', 'Austria', 'Austrian', 'Authority', 'Ave.', 'Avenue', 'B', 'B-52s', 'B.', 'BMT', 'Balaguer', "Balaguer's", 'Bald', 'Baltimore', 'Bangkok', 'Baptist', 'Baptists', 'Bar', 'Barry', 'Bashir', 'Basler', 'Batista', "Batista's", 'Be', 'Bea', 'Beach', 'Beatitudes', 'Because', 'Becket', 'Beebe', "Beebe's", 'Before', 'Behan', 'Being', 'Belated', 'Belgian', 'Bell', 'Ben-Gurion', 'Benefactor', "Benefactor's", 'Benet', 'Benjamin', 'Berlin', "Berlin's", 'Berlin-West', 'Berliners', 'Bermuda', 'Berniece', 'Bertha', 'Bertrand', 'Besides', 'Best', 'Betancourt', 'Beth', 'Better', 'Betting', 'Beverly', 'Bible', 'Biblical', 'Big', 'Biggest', 'Bill', 'Billie', 'Birch', 'Birds', 'Bishop', 'Bismarck', 'Bitterness', 'Bldg.', 'Bless', 'Blessed', 'Blueprints', 'Board', "Board's", 'Bodenheim', 'Boland', 'Bolivar', 'Bonn', 'Bontempo', 'Borak', 'Bore', 'Borough', 'Bosch', 'Bostitch', 'Bo ...
#                  cities  citizen citizens   citrus     city   city's
#        fiction        3        0        1        0       18        0
#           lore       15        2        7        0       40        3
# belles_lettres       10       11       17        0       36        1
#     government       26        0        9        0        7        0
#        learned       20        2       13        0       16        3

# %%
from nltk import PCFG
from nltk.corpus import treebank
from nltk import treetransforms
from nltk import induce_pcfg
from nltk.parse import pchart
toy_pcfg1 = PCFG.fromstring("""
    S -> NP VP [1.0]
    NP -> Det N [0.5] | NP PP [0.25] | 'John' [0.1] | 'I' [0.15]
    Det -> 'the' [0.8] | 'my' [0.2]
    N -> 'man' [0.5] | 'telescope' [0.5]
    VP -> VP PP [0.1] | V NP [0.7] | V [0.2]
    V -> 'ate' [0.35] | 'saw' [0.65]
    PP -> P NP [1.0]
    P -> 'with' [0.61] | 'under' [0.39]
""")
pcfg_prods = toy_pcfg1.productions()
pcfg_prod = pcfg_prods[2]
print('A PCFG production:', pcfg_prod)
print('pcfg_prod.lhs()  =>', pcfg_prod.lhs())
print('pcfg_prod.rhs()  =>', pcfg_prod.rhs())
print('pcfg_prod.prob() =>', pcfg_prod.prob())
# Out:
# A PCFG production: NP -> NP PP [0.25]
# pcfg_prod.lhs()  => NP
# pcfg_prod.rhs()  => (NP, PP)
# pcfg_prod.prob() => 0.25
